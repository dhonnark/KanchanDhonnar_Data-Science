# %%
import numpy as np
import pandas as pd
from sklearn import linear_model
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import r2_score

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv(r'C:\Users\hp\Downloads\tvmarketing-1-1_1729437291501 (1).csv')

# %%
data
# Out:
#         TV  Sales
# 0    230.1   22.1
# 1     44.5   10.4
# 2     17.2    9.3
# 3    151.5   18.5
# 4    180.8   12.9
# ..     ...    ...
# 195   38.2    7.6
# 196   94.2    9.7
# 197  177.0   12.8
# 198  283.6   25.5
# 199  232.1   13.4
#
# [200 rows x 2 columns]

# %%
data.describe()
# Out:
#                TV       Sales
# count  200.000000  200.000000
# mean   147.042500   14.022500
# std     85.854236    5.217457
# min      0.700000    1.600000
# 25%     74.375000   10.375000
# 50%    149.750000   12.900000
# 75%    218.825000   17.400000
# max    296.400000   27.000000

# %%
x=data[['TV']]

# %%
y=data[['Sales']]

# %%
model=linear_model.LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
sns.regplot(x="TV",y="Sales",data=data)
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %%
#note when we pass x values to the model predict it will predict the sales value
predictions=model.predict(x)
data['pred']=np.round(predictions,1)

# %%
data
# Out:
#         TV  Sales  pred
# 0    230.1   22.1  18.0
# 1     44.5   10.4   9.1
# 2     17.2    9.3   7.9
# 3    151.5   18.5  14.2
# 4    180.8   12.9  15.6
# ..     ...    ...   ...
# 195   38.2    7.6   8.8
# 196   94.2    9.7  11.5
# 197  177.0   12.8  15.4
# 198  283.6   25.5  20.5
# 199  232.1   13.4  18.1
#
# [200 rows x 3 columns]

# %%
#as we can see the actuals and the prected values side by side here
r2_score(data[['Sales']],data[['pred']])
# Out:
# 0.6119822258895882

# %%
new_data=pd.read_csv(r'C:\Users\hp\eurovision_1998 to 2012.csv')

# %%
new_data
# Out:
#      Unnamed: 0  Year      Country                 Region  \
# 0             1  2009    Lithuania  Former Socialist Bloc
# 1             2  2009       Israel            Independent
# 2             3  2009       France         Western Europe
# 3             4  2009       Sweden            Scandinavia
# 4             5  2009      Croatia      Former Yugoslavia
# ..          ...   ...          ...                    ...
# 643         644  2010     Slovenia      Former Yugoslavia
# 644         645  2010       Sweden            Scandinavia
# 645         646  2010  Switzerland         Western Europe
# 646         647  2010       Turkey            Independent
# 647         648  2010      Ukraine  Former Socialist Bloc
#
#                             Artist                       Song Artist.gender  \
# 0                       Sasha Son                        Love          Male
# 1               Noa and Mira Awad   There Must Be Another Way        Female
# ...

# %%
new_data.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Country', 'Region', 'Artist', 'Song',
#        'Artist.gender', 'Group.Solo', 'Place', 'Points', 'Home.Away.Country',
#        'Home.Away.Region', 'Is.Final', 'Semi.Final.Number', 'Song.In.English',
#        'Song.Quality', 'Normalized.Points', 'energy', 'duration',
#        'acousticness', 'danceability', 'tempo', 'speechiness', 'key',
#        'liveness', 'time_signature', 'mode', 'loudness', 'valence',
#        'Happiness'],
#       dtype='object')

# %%
x=new_data.drop(['Year', 'Country', 'Region', 'Artist', 'Song',
       'Artist.gender', 'Group.Solo', 'Place', 'Points', 'Home.Away.Country',
       'Home.Away.Region','Semi.Final.Number','Song.Quality'],axis=1)
x
# Out:
#      Unnamed: 0  Is.Final  Song.In.English  Normalized.Points    energy  \
# 0             1         1                1           0.009442  0.678258
# 1             2         1                1           0.021757  0.794093
# 2             3         1                0           0.043924  0.574628
# 3             4         1                1           0.013547  0.672746
# 4             5         1                0           0.018473  0.733959
# ..          ...       ...              ...                ...       ...
# 643         644         0                0           0.005445  0.913209
# 644         645         0                1           0.056261       NaN
# 645         646         0                0           0.001815       NaN
# 646         647         0                1           0.107078  0.911007
# 647         648         0                1           0.069873  0.413793
#
#       duration  acousticness  danceability    tempo  speechiness   key  \
# ...

# %%
y=new_data[['Song.Quality']]
y
# Out:
#      Song.Quality
# 0        0.651053
# 1        1.323627
# 2        2.586431
# 3        0.864872
# 4        0.931014
# ..            ...
# 643      0.832668
# 644      3.711427
# 645      1.101155
# 646      5.845377
# 647      3.785186
#
# [648 rows x 1 columns]

# %%
# so now here linear regression graph is y=m1x1+m2x2+m3x3+c
#then we drop unnecessary columns # then we will use label encoder to convert the ordinal column 
#then we split the data in train and test 
#then we use linear regression on training data
#then we do r2 score for model accuracy

# %%
Model=linear_model.LinearRegression()

# %%
x.replace(NAN,'0')
