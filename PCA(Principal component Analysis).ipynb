# %%
import pandas as pd
from sklearn.decomposition import PCA

# %%
df=pd.read_csv(r'C:\Users\hp\AppData\HR_comma_sep.csv')

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# ...

# %%
X=df[['satisfaction_level','last_evaluation','number_project','average_montly_hours']]
X
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours
# 0                       157
# 1                       262
# 2                       272
# 3                       223
# 4                       159
# ...                     ...
# 14994                   151
# ...

# %% [raw]
# NOW we will reduce the above 4 features using PCA

# %%
#creating principal components
principal_component=PCA().fit_transform(X)

# %%
print(principal_component)
# Out:
# [[-4.40667366e+01 -1.34416692e+00 -2.94003878e-01 -3.88366943e-02]
#  [ 6.09588667e+01  5.64273671e-01  2.18538065e-01  1.67940003e-02]
#  [ 7.09790243e+01  2.48278304e+00 -4.06138259e-01  6.19942230e-02]
#  ...
#  [-5.80659832e+01 -1.19915499e+00 -2.98491718e-01 -2.67386117e-02]
#  [ 7.89683861e+01  1.40421268e+00 -4.23835203e-01  1.75441714e-01]
#  [-4.30668010e+01 -1.35451099e+00 -3.05909487e-01 -4.77827005e-02]]

# %%
#as we have not told the PCA to exactly how many columns it should reduce ,it reducesd the values keeping the number of columns same
# NOW we will tell it

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
pca=PCA()

# %%
pca_values=np.arange(pca.n_components) + 1
plt.plot(pca_values)

# %%
#pca.explained_variance_ratio_

# %% [raw]
# # WE WILL REDUCE THE DATA TO ONLY 2 COLUMNS WE GOT IT BY ELBOW METHOD BY ABOVE CODE

# %%
#NOW

pca=PCA(n_components=2)
PRINCIPALCOMPONENT=pca.fit_transform(X)

# %%
print(PRINCIPALCOMPONENT)
# Out:
# [[-44.06673664  -1.34416692]
#  [ 60.95886671   0.56427367]
#  [ 70.97902431   2.48278304]
#  ...
#  [-58.06598323  -1.19915499]
#  [ 78.96838614   1.40421268]
#  [-43.06680103  -1.35451099]]
